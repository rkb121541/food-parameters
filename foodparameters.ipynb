# %% [markdown]
# ### Import stuff

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from io import StringIO

# %% [markdown]
# ### Reading the csv with all data

# %%
data = pd.read_csv("all_meals_sample.csv")
display(data)
# Out:
#          date  round  meal_id                                 item_name  \
# 0    12/11/20      1        1  omelet, western, prepared with added fat
# 1    12/11/20      1        1                                  tortilla
# 2    12/11/20      1        1                   iced tea, diet, Snapple
# 3    12/11/20      1        2                   chewing gum, sugar free
# 4    12/11/20      1        3  omelet, western, prepared with added fat
# ..        ...    ...      ...                                       ...
# 117    2/3/21      2       16            fried chicken thigh, with skin
# 118    2/3/21      2       16                           tomatoes, fresh
# 119    2/3/21      2       16                                mayonnaise
# 120    2/3/21      2       16                   lettuce, romaine, fresh
# 121    2/3/21      2       16                              french fries
#
#     quantity       measure  esha_code  gov_code  cals_kcal  prot_g  ...  \
# 0      2-Jan           Cup     124464  32130890     193.91   13.01  ...
# 1        0.9  Ounce-weight     157895  52215000      66.85    1.77  ...
# 2         16   Fluid ounce     129990  92309020       4.80    0.00  ...
# 3          1         Stick     120338  91802000       4.82    0.00  ...
# 4      2-Jan           Cup     124464  32130890     193.91   13.01  ...
# ..       ...           ...        ...       ...        ...     ...  ...
# 117      5.5  Ounce-weight     156970  24157300     422.55   29.59  ...
# 118        2  Ounce-weight     119089  74101000      10.21    0.50  ...
# 119        1    Tablespoon     120064  83107000     102.00    0.14  ...
# 120    4-Mar           Cup     118826  72116000       3.94    0.36  ...
# 121        8  Ounce-weight     118661  71401030     707.60    7.78  ...
#
#      portion  portion_size_notes  lact_g_73  lact_g_175       day  first_day  \
# 0        NaN                 NaN        NaN         NaN  12/11/20   12/11/20
# 1        NaN                 NaN        NaN         NaN  12/11/20   12/11/20
# 2        NaN                 NaN        NaN         NaN  12/11/20   12/11/20
# 3        NaN                 NaN        NaN         NaN  12/11/20   12/11/20
# 4        NaN                 NaN        NaN         NaN  12/11/20   12/11/20
# ..       ...                 ...        ...         ...       ...        ...
# 117      NaN                 NaN        NaN         NaN    2/3/21    1/21/21
# 118      NaN                 NaN        NaN         NaN    2/3/21    1/21/21
# 119      NaN                 NaN        NaN         NaN    2/3/21    1/21/21
# 120      NaN                 NaN        NaN         NaN    2/3/21    1/21/21
# 121      NaN                 NaN        NaN         NaN    2/3/21    1/21/21
#
#      last_day  day_of_round  weekend  time_shift
# 0    12/24/20             1    False       False
# 1    12/24/20             1    False       False
# 2    12/24/20             1    False       False
# 3    12/24/20             1    False       False
# 4    12/24/20             1    False       False
# ..        ...           ...      ...         ...
# 117    2/3/21            14    False       False
# 118    2/3/21            14    False       False
# 119    2/3/21            14    False       False
# 120    2/3/21            14    False       False
# 121    2/3/21            14    False       False
#
# [122 rows x 206 columns]

# %% [markdown]
# ### Loading table and parsing it

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
}

url = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3925198/table/tab2/?report=objectonly'

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find_all('table')[0]

# original table
display_table = pd.read_html(StringIO(str(table)))[0]

# %%
df = display_table
df.drop(df.columns[1:3], axis=1, inplace=True) # remove weighted number of articles - not important, also removed raw inflammatory score

# Or rename the existing DataFrame (rather than creating a copy) 
df.rename(columns={df.columns[1]: 'overall inflammatory score', df.columns[2]: 'mean', df.columns[3]: "sd"}, inplace=True)

# %%
for index, row in df.iterrows():
    for col in df.columns:
        for i in range(len(row[col])):
            if row[col][i] == '·': 
                row[col] = row[col][:i] + "." + row[col][i+1:]
            elif row[col][i] == '−': 
                row[col] = row[col][:i] + "-" + row[col][i+1:]
df
# Out:
#          Food parameter overall inflammatory score   mean     sd
# 0           Alcohol (g)                     -0.278  13.98   3.72
# 1      Vitamin B12 (μg)                      0.106   5.15   2.70
# 2       Vitamin B6 (mg)                     -0.365   1.47   0.74
# 3       β-Carotene (μg)                     -0.584   3718   1720
# 4          Caffeine (g)                     -0.110   8.05   6.67
# 5      Carbohydrate (g)                      0.097  272.2   40.0
# 6      Cholesterol (mg)                      0.110  279.4   51.2
# 7         Energy (kcal)                      0.180   2056    338
# 8          Eugenol (mg)                     -0.140   0.01   0.08
# 9         Total fat (g)                      0.298   71.4   19.4
# 10            Fibre (g)                     -0.663   18.8    4.9
# 11      Folic acid (μg)                     -0.190  273.0   70.7
# 12           Garlic (g)                     -0.412   4.35   2.90
# 13           Ginger (g)                     -0.453   59.0   63.2
# 14              Fe (mg)                      0.032  13.35   3.71
# 15              Mg (mg)                     -0.484  310.1  139.4
# 16             MUFA (g)                     -0.009   27.0    6.1
# 17          Niacin (mg)                     -0.246  25.90  11.77
# 18  n-3 Fatty acids (g)                     -0.436   1.06   1.06
# 19  n-6 Fatty acids (g)                     -0.159  10.80   7.50
# 20            Onion (g)                     -0.301   35.9   18.4
# 21          Protein (g)                      0.021   79.4   13.9
# 22             PUFA (g)                     -0.337  13.88   3.76
# 23      Riboflavin (mg)                     -0.068   1.70   0.79
# 24          Saffron (g)                     -0.140   0.37   1.78
# 25    Saturated fat (g)                      0.373   28.6    8.0
# 26              Se (μg)                     -0.191   67.0   25.1
# 27         Thiamin (mg)                     -0.098   1.70   0.66
# 28        Trans fat (g)                      0.229   3.15   3.75
# 29        Turmeric (mg)                     -0.785  533.6  754.3
# 30       Vitamin A (RE)                     -0.401  983.9  518.6
# 31       Vitamin C (mg)                     -0.424  118.2  43.46
# 32       Vitamin D (μg)                     -0.446   6.26   2.21
# 33       Vitamin E (mg)                     -0.419   8.73   1.49
# 34              Zn (mg)                     -0.313   9.84   2.19
# 35  Green/black tea (g)                     -0.536   1.69   1.53
# 36     Flavan-3-ol (mg)                     -0.415   95.8   85.9
# 37        Flavones (mg)                     -0.616   1.55   0.07
# 38       Flavonols (mg)                     -0.467  17.70   6.79
# 39      Flavonones (mg)                     -0.250  11.70   3.82
# 40  Anthocyanidins (mg)                     -0.131  18.05  21.14
# 41     Isoflavones (mg)                     -0.593   1.20   0.20
# 42           Pepper (g)                     -0.131  10.00   7.07
# 43   Thyme/oregano (mg)                     -0.102   0.33   0.99
# 44        Rosemary (mg)                     -0.013   1.00  15.00

# %%
count = 0
for col in df.columns[1:]:
    for row in df.iterrows():
        count += 1
count
# Out:
# 135

# %% [markdown]
# #### How to calculate DII score
# https://pubs.sciepub.com/jfnr/8/4/2/index.html#:~:text=The%20first%20step%20to%20calculate,to%20a%20centered%20percentile%20score.

# %%
food_params = {}
l = list(display_table['Food parameter'])

# %%
for item in l:
    food_params[item] = None

food_params['Alcohol (g)'] = 'alc_g'
food_params['Vitamin B12 (μg)'] = 'vit_b12_mcg'
food_params['Vitamin B6 (mg)'] = 'vit_b6_mg'
food_params['β-Carotene (μg)'] = 'beta_caro_mcg'
food_params['Caffeine (g)'] = 'caff_mg' # need to convert units
food_params['Carbohydrate (g)'] = 'carb_g'
food_params['Cholesterol (mg)'] = 'chol_mg'
food_params['Energy (kcal)'] = 'cals_kcal'
# food_params['Eugenol (mg)'] = 
food_params['Total fat (g)'] = 'fat_g'
food_params['Fibre (g)'] = 'tot_fib_g'
food_params['Folic acid (μg)'] = 'fol_acid_mcg'
# food_params['Garlic (g)'] = 
# food_params['Ginger (g)'] = 
food_params['Fe (mg)'] = 'iron_mg'
food_params['Mg (mg)'] = 'magn_mg'
food_params['MUFA (g)'] = 'mono_fat_g'
# food_params['Niacin (mg)'] = 
food_params['n-3 Fatty acids (g)'] = 'omega3_g'
food_params['n-6 Fatty acids (g)'] = 'omega6_g'
# food_params['Onion (g)'] =  
food_params['Protein (g)'] = 'prot_g'
food_params['PUFA (g)'] = 'poly_fat_g'
# food_params['Riboflavin (mg)'] = 
# food_params['Saffron (g)'] =
food_params['Saturated fat (g)'] = 'sat_fat_g'
food_params['Se (μg)'] = 'sel_mcg'
# food_params['Thiamin (mg)'] = 
food_params['Trans fat (g)'] = 'trans_fat_g'
# food_params['Turmeric (mg)'] = 
food_params['Vitamin A (RE)'] = 'vit_a_re_mcg'
food_params['Vitamin C (mg)'] = 'vit_c_mg'
food_params['Vitamin D (μg)'] = 'vit_d_mcg_mcg'
food_params['Vitamin E (mg)'] = 'vit_e_a_toco_mg'
food_params['Zn (mg)'] = 'zinc_mg'
# food_params['Green/black tea (g)'] = 
# food_params['Flavan-3-ol (mg)'] = 
# food_params['Flavones (mg)'] = 
# food_params['Flavonols (mg)'] = 
# food_params['Flavonones (mg)'] = 
# food_params['Anthocyanidins (mg)'] = 
# food_params['Isoflavones (mg)'] = 
# food_params['Pepper (g)'] = 
# food_params['Thyme/oregano (mg)'] = 
# food_params['Rosemary (mg)'] =

# %%
new_dict = dict([(value, key) for key, value in food_params.items()])
